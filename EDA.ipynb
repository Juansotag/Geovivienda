# %%
from selenium import webdriver  
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.common.by import By

# %% [markdown]
# # Versión experimental

# %%
from selenium import webdriver  
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.common.by import By

opts = Options()
opts.add_argument("--start-maximized")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=opts
)

# Acceder a la página principal
driver.get("https://www.fincaraiz.com.co/arriendo/apartamentos-y-apartaestudios/bogota/bogota-dc")
time.sleep(3)

# Creamos una lista para almacenar los links
links_dataset = []

for j in range(1, 10):
    print(f"\nProcesando página {j}")
    time.sleep(2)
    
    # Buscar TODOS los anuncios usando el patrón del XPATH que funciona
    anuncios_encontrados = 0
    for i in range(1, 30):  # Intentar hasta 30 posiciones por página
        try:
            driver.execute_script("window.scrollBy(0, 300);")
            time.sleep(0.1)
            
            anuncio = driver.find_element(
                By.XPATH,
                f"/html/body/div[2]/div[2]/div/section/div[{i}]/div/div/div[2]/a[2]"
            )
            link = anuncio.get_attribute("href")
            
            if link and link not in links_dataset:
                links_dataset.append(link)
                anuncios_encontrados += 1
                print(f"Link {anuncios_encontrados}: {link}")
        except:
            # Silenciosamente continuar si no encuentra el elemento
            pass
    
    print(f"Anuncios encontrados en página {j}: {anuncios_encontrados}")
    print(f"Total acumulado: {len(links_dataset)}")
    
    # Pasar a siguiente página
    time.sleep(3)
    siguiente = driver.find_element(By.LINK_TEXT, ">")
    print("Pasando página")
    siguiente.click()
    time.sleep(7)

# Total de links recolectados
print(f"\nTotal de links recolectados: {len(links_dataset)}")

# Cerramos el navegador
driver.quit()
# Out:
# Procesando página 1
# Link 1: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-nuevo-country-bogota/193460052
# Link 2: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-lagos-de-torca-bogota/192813390
# Link 3: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-usatama-bogota/193380265
# Link 4: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-puente-aranda-bogota/193506520
# Link 5: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-pinar-de-suba-bogota/193463557
# Link 6: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chapinero-alto-bogota/193295823
# Link 7: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-bogota/193470251
# Link 8: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-engativa-bogota/193482297
# Link 9: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chapinero-alto-bogota/193458129
# Link 10: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-santa-barbara-bogota/193473808
# Link 11: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-san-patricio-bogota/193431079
# Link 12: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chapinero-bogota/193493548
# Link 13: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chapinero-bogota/193063091
# Link 14: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-americas-central-bogota/193478079
# Link 15: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-el-chico-bogota/192750131
# Link 16: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-chapinero-bogota/193345853
# Link 17: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-navarra-bogota/193522990
# Link 18: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-cabrera-bogota/193097402
# Link 19: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-estanzuela-bogota/193455591
# Link 20: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-el-chico-bogota/193363100
# Anuncios encontrados en página 1: 20
# Total acumulado: 20
# Pasando página
#
# Procesando página 2
# Link 1: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bosa-la-amistad-bogota/193324452
# Link 2: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-paloquemao-bogota/193299543
# Link 3: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-los-rosales-bogota/193406957
# Link 4: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-centro-internacional-bogota/193403863
# Link 5: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-usaquen-bogota/193520618
# Link 6: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-chapinero-bogota/3458644
# Link 7: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-barrios-unidos-bogota/193417812
# Link 8: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bosque-medina-bogota/193502386
# Link 9: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-lagos-de-torca-bogota/193299473
# Link 10: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-las-aguas-bogota/191974102
# Link 11: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-fontibon-bogota/191955675
# Link 12: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-las-nieves-bogota/193344539
# Link 13: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-floresta-bogota/193538892
# Link 14: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bella-suiza-bogota/193388722
# Link 15: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-venecia-bogota/193449006
# Link 16: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-san-jose-v-sector-bogota/193414584
# Link 17: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-teusaquillo-bogota/193446372
# Link 18: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-alto-bogota/193401861
# Link 19: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-emaus-bogota/193507768
# Link 20: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-el-batan-bogota/193520529
# Anuncios encontrados en página 2: 20
# Total acumulado: 40
# Pasando página
#
# Procesando página 3
# Link 1: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-olaya-bogota/193317390
# Link 2: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-navarra-bogota/193385630
# Link 3: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-santa-barbara-central-bogota/193336475
# Link 4: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bosque-de-pinos-bogota/192750149
# Link 5: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-los-monjes-bogota/193452880
# Link 6: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-el-virrey-bogota/193528761
# Link 7: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-macarena-bogota/192827261
# Link 8: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-el-redil-bogota/193267147
# Link 9: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-ricaurte-bogota/193410094
# Link 10: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-centro-internacional-bogota/193420316
# Link 11: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-engativa-bogota/192677669
# Link 12: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bogota/193350926
# Link 13: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chapinero-bogota/193450343
# Link 14: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-norte-bogota/193068433
# Link 15: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-el-chico-bogota/193378438
# Link 16: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-quinta-paredes-bogota/193472326
# Link 17: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bella-suiza-bogota/193509567
# Link 18: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-fontibon-bogota/10267404
# Link 19: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-lagos-de-torca-bogota/193442546
# Link 20: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-cabrera-bogota/193428692
# Anuncios encontrados en página 3: 20
# Total acumulado: 60
# Pasando página
#
# Procesando página 4
# Link 1: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-santa-barbara-bogota/193371665
# Link 2: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-santa-helenita-bogota/193455159
# Link 3: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-modelia-bogota/193281252
# Link 4: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-las-nieves-bogota/193112027
# Link 5: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-chapinero-central-bogota/193141540
# Link 6: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-chico-norte-bogota/193485149
# Link 7: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-santa-barbara-occidental-bogota/192750095
# Link 8: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-jose-joaquin-vargas-bogota/193402923
# Link 9: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-chapinero-central-bogota/193485893
# Link 10: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-san-patricio-bogota/193493270
# Link 11: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-santa-barbara-central-bogota/193466991
# Link 12: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-alto-bogota/193241881
# Link 13: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-colina-campestre-bogota/193409625
# Link 14: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-bogota/193336407
# Link 15: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-norte-bogota/193046084
# Link 16: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-carolina-bogota/193502839
# Link 17: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-modelia-occidental-bogota/193428194
# Link 18: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-veramonte-macana-bogota/193434737
# Link 19: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-norte-bogota/193463260
# Link 20: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-norte-bogota/10792307
# Link 21: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-norte-bogota/193172388
# Anuncios encontrados en página 4: 21
# Total acumulado: 81
# Pasando página
#
# Procesando página 5
# Link 1: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-chico-navarra-bogota/193551488
# Link 2: https://www.fincaraiz.com.co/apartamento-en-arriendo-en-la-salle-bogota/193290107
# Link 3: https://www.fincaraiz.com.co/apartaestudio-en-arriendo-en-belalcazar-bogota/10276235
# Anuncios encontrados en página 5: 3
# Total acumulado: 84
# Pasando página
#
# Procesando página 6
# Anuncios encontrados en página 6: 0
# Total acumulado: 84
# Pasando página
#
# Procesando página 7
# Anuncios encontrados en página 7: 0
# Total acumulado: 84
